# %% [markdown]
# # ME 498 HW3 Submission

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm

# %%
#Problem1.1
miu=10
sigma=2.5
size=2
k=3
print('UCL=%.3f'%(miu+k*sigma/np.sqrt(size)))
print('CL=%.3f'%(miu))
print('LCL=%.3f'%(miu-k*sigma/np.sqrt(size)))
# Out:
# UCL=15.303
# CL=10.000
# LCL=4.697

# %%
#Problem1.2
d2=1.128
d3=0.853
print('UCL=%.3f'%(d2*sigma+k*d3*sigma))
print('CL=%.3f'%(d2*sigma))
print('LCL=%.3f'%(d2*sigma-k*d3*sigma))
# Out:
# UCL=9.218
# CL=2.820
# LCL=-3.578

# %%
#Problem1.3
k=2
print('for x-bar control chart')
print('UCL=%.3f'%(miu+k*sigma/np.sqrt(size)))
print('CL=%.3f'%(miu))
print('LCL=%.3f'%(miu-k*sigma/np.sqrt(size)))
print('for R control chart')
print('UCL=%.3f'%(d2*sigma+k*d3*sigma))
print('CL=%.3f'%(d2*sigma))
print('LCL=%.3f'%(0))
# Out:
# for x-bar control chart
# UCL=13.536
# CL=10.000
# LCL=6.464
# for R control chart
# UCL=7.085
# CL=2.820
# LCL=0.000

# %%
#Problem2.1
xbar=6000/30
rbar=150/30
a2=0.483
print('for xbar')
print('UCL=%.3f'%(xbar+a2*rbar))
print('CL=%.3f'%(xbar))
print('LCL=%.3f'%(xbar-a2*rbar))
d4=2.004
d3=0
print('for rbar')
print('UCL=%.3f'%(d4*rbar))
print('CL=%.3f'%(rbar))
print('LCL=%.3f'%(d3*rbar))
# Out:
# for xbar
# UCL=202.415
# CL=200.000
# LCL=197.585
# for rbar
# UCL=10.020
# CL=5.000
# LCL=0.000

# %%
#Problem2.2
sigma=rbar/2.534
sigmabar=sigma/np.sqrt(6)
prob=norm.cdf(((xbar+3*sigmabar)-199)/(sigmabar))-norm.cdf(((xbar-3*sigmabar)-199)/(sigmabar))
print('beta risk is %.3f'%prob)
# Out:
# beta risk is 0.961

# %%
#Problem3.1
r=[0.0008,0.0009,0.0009,0.0002,0.0004,0.0009,0.0003,0.0003,0.0005,0.0003,0.0005,0.0018,0.0008,0.0010,0.0001]
rbar=np.average(r)
d4=2.114
d3=0
ucl1=d4*rbar
cl1=rbar
lcl1=d3*rbar
time=np.linspace(1,15,15)

plt.plot(time,r,c='blue',marker='.',alpha=0.5,label='Configuration 1')
plt.hlines(ucl1,1,15,linestyle="-")
plt.hlines(cl1,1,15,linestyle="-")
plt.hlines(lcl1,1,15,linestyle="-")
plt.title('R-chart Phase1')
# Out:
# Text(0.5,1,'R-chart Phase1')

# %%
#Problem3.1
r=[0.0008,0.0009,0.0009,0.0002,0.0004,0.0009,0.0003,0.0003,0.0005,0.0003,0.0005,0.0008,0.0010,0.0001]
rbar=np.average(r)
d4=2.114
d3=0
ucl1=d4*rbar
cl1=rbar
lcl1=d3*rbar
time=np.linspace(1,14,14)

plt.plot(time,r,c='blue',marker='.',alpha=0.5,label='Configuration 1')
plt.hlines(ucl1,1,15,linestyle="-")
plt.hlines(cl1,1,15,linestyle="-")
plt.hlines(lcl1,1,15,linestyle="-")
plt.title('R-chart Phase1')
# Out:
# Text(0.5,1,'R-chart Phase1')

# %%
#Problem3.2
r=[0.0008,0.0009,0.0009,0.0002,0.0004,0.0009,0.0003,0.0003,0.0005,0.0003,0.0005,0.0008,0.0010,0.0001]
rbar=np.average(r)
d4=2.114
d3=0
ucl1=d4*rbar
cl1=rbar
lcl1=d3*rbar
print('ucl=%f'%ucl1)
print('lcl=%f'%lcl1)
# Out:
# ucl=0.001193
# lcl=0.000000

# %%
#Problem3.3
r=[0.0008,0.0009,0.0009,0.0002,0.0004,0.0009,0.0003,0.0003,0.0005,0.0003,0.0005,0.0008,0.0010,0.0001]
avr=np.average(r)
#summ=0
#for i in range(0,14):
#    summ=((r[i]-avr)**2)
#dev=np.sqrt(summ/13)
#dev
dev=avr*0.864/2.326
dev
# Out:
# 0.00020960569954551038

# %%
#Problem3.4
ucl1=0.3220+3*dev
lcl1=0.3220-3*dev
ucl2=0.3200+3*dev
lcl2=0.3200-3*dev
total=[ 0.3211, 0.3219, 0.3216, 0.3219, 0.3216,
 0.3219, 0.3214, 0.3213, 0.3210, 0.3213,
 0.3210, 0.3219, 0.3210, 0.3213, 0.3212,
 0.3211, 0.3211, 0.3210, 0.3212, 0.3211,
 0.3207, 0.3210, 0.3209, 0.3210, 0.3206,
 0.3203, 0.3212, 0.3210, 0.3210, 0.3212,
 0.3207, 0.3209, 0.3209, 0.3210, 0.3208,
0.3210, 0.3208, 0.3207, 0.3207, 0.3208,
 0.3212, 0.3210, 0.3209, 0.3207, 0.3209,
 0.3210, 0.3212, 0.3209, 0.3209, 0.3212,
 0.3207, 0.3208, 0.3209, 0.3209, 0.3212,
 0.3194, 0.3212, 0.3210, 0.3206, 0.3209,
 0.3204, 0.3207, 0.3210, 0.3210, 0.3202,
 0.3207, 0.3205, 0.3215, 0.3210, 0.3215,
 0.3209,0.3209, 0.3209, 0.3208, 0.3209]
signal=0
defect=0
for i in range(0,75):
    signal=total[i]
    if ((signal>ucl1) or  (signal<lcl2)):
        print(i)
        defect+=1
print(defect)
# Out:
# 0

# %%
#Problem4.1
miu=10
sigma=2.5
b6=2.088
c4=0.9213
b5=0
ucl=2.088*sigma
cl=c4*sigma
lcl=b5*sigma
print('ucl=%.4f'%ucl)
print('cl=%.4f'%cl)
print('lcl=%.4f'%lcl)
# Out:
# ucl=5.2200
# cl=2.3033
# lcl=0.0000

# %%
#Problem4.2
miu=10
sigma=2.5
c4=0.9213
p=np.sqrt(1-c4**2)
ucl=(c4+2*p)*sigma
lcl=(c4-2*p)*sigma
print('ucl=%.4f'%ucl)
print('lcl=%.4f'%lcl)
# Out:
# ucl=4.2475
# lcl=0.3590

# %%
chart1_a
# Out:
# array([[1.4314, 1.3592, 1.6075, 1.4666, 1.6109, 1.4951, 0.2517],
#        [1.4284, 1.4871, 1.4932, 1.4324, 1.5674, 1.4817, 0.139 ],
#        [1.5028, 1.6352, 1.3841, 1.2831, 1.5507, 1.4712, 0.3521],
#        [1.5604, 1.2735, 1.5265, 1.4363, 1.6441, 1.4882, 0.3706],
#        [1.5955, 1.5451, 1.3574, 1.3281, 1.4198, 1.4492, 0.2674],
#        [1.6274, 1.5064, 1.8366, 1.4177, 1.5144, 1.5805, 0.4189],
#        [1.419 , 1.4303, 1.6637, 1.6067, 1.5519, 1.5343, 0.2447],
#        [1.3884, 1.7277, 1.5355, 1.5176, 1.3688, 1.5076, 0.3589],
#        [1.4039, 1.6697, 1.5089, 1.4627, 1.522 , 1.5134, 0.2658],
#        [1.4158, 1.7667, 1.4278, 1.5928, 1.4181, 1.5242, 0.3509],
#        [1.5821, 1.3355, 1.5777, 1.3908, 1.7559, 1.5284, 0.4204],
#        [1.2856, 1.4106, 1.4447, 1.6398, 1.1928, 1.3947, 0.447 ],
#        [1.4951, 1.4036, 1.5893, 1.6458, 1.4969, 1.5261, 0.2422],
#        [1.3589, 1.2863, 1.5996, 1.2497, 1.5471, 1.4083, 0.3499],
# ...

# %%
#Problem5.1
chart1 = pd.read_csv('chart1.csv',header = None,  index_col = None) # Read .csv file with pandas
chart1_a = np.asanyarray(chart1)
chart2 = pd.read_csv('chart2.csv',header = None,  index_col = None) # Read .csv file with pandas
chart2_a = np.asanyarray(chart2)
si=[]
ssum=0
for i in range (0,25):
    si.append(np.sqrt(((chart1_a[i][0]-chart1_a[i][5])**2+(chart1_a[i][1]-chart1_a[i][5])**2+(chart1_a[i][2]-chart1_a[i][5])**2+(chart1_a[i][3]-chart1_a[i][5])**2
            +(chart1_a[i][4]-chart1_a[i][5])**2)/4))
    ssum+=np.sqrt(((chart1_a[i][0]-chart1_a[i][5])**2+(chart1_a[i][1]-chart1_a[i][5])**2+(chart1_a[i][2]-chart1_a[i][5])**2+(chart1_a[i][3]-chart1_a[i][5])**2
            +(chart1_a[i][4]-chart1_a[i][5])**2)/4)
sbar=ssum/25
sigma=sbar/0.94
print('estimated sigma is %f'%sigma)
# Out:
# estimated sigma is 0.139952

# %%
#Problem5.2
xbarsum=0
for i in range (0,25):
    xbarsum+=chart1_a[i][5]
xbarbar=xbarsum/25
print('ucl=%f'%(xbarbar+1.427*sbar))
print('cl=%f'%(xbarbar))
print('lcl=%f'%(xbarbar-1.427*sbar))
# Out:
# ucl=1.693332
# cl=1.505604
# lcl=1.317876

# %%
#Problem5.3
print('ucl=%f'%(sbar*2.089))
print('cl=%f'%(sbar))
print('lcl=%f'%(sbar*0))
# Out:
# ucl=0.274818
# cl=0.131555
# lcl=0.000000

# %%
#Problem5.4
plt.figure(figsize=(8,4))
time=np.linspace(1,25,25)
xbar_a=chart1_a[:,5]
plt.plot(time,xbar_a,c='blue',marker='.',alpha=0.5,label='Configuration 1')
plt.hlines(xbarbar+1.427*sbar,1,25,linestyle="-")
plt.hlines(xbarbar,1,25,linestyle="-")
plt.hlines(xbarbar-1.427*sbar,1,25,linestyle="-")
plt.title('x bar chart Phase1') 
xbar_a
# Out:
# array([1.5119, 1.4951, 1.4817, 1.4712, 1.4882, 1.4492, 1.5805, 1.5343,
#        1.5076, 1.5134, 1.5242, 1.5284, 1.3947, 1.5261, 1.4083, 1.5344,
#        1.4874, 1.4573, 1.5777, 1.506 , 1.4691, 1.539 , 1.5592, 1.5688,
#        1.5264])

# %%
plt.figure(figsize=(8,4))
time=np.linspace(1,25,25)
xbar_a=chart1_a[:,5]
plt.plot(time,si,c='blue',marker='.',alpha=0.5,label='Configuration 1')
plt.hlines(sbar*2.089,1,25,linestyle="-")
plt.hlines(sbar,1,25,linestyle="-")
plt.hlines(0,1,25,linestyle="-")
plt.title('s chart Phase1') 
xbar_a
# Out:
# array([1.5119, 1.4951, 1.4817, 1.4712, 1.4882, 1.4492, 1.5805, 1.5343,
#        1.5076, 1.5134, 1.5242, 1.5284, 1.3947, 1.5261, 1.4083, 1.5344,
#        1.4874, 1.4573, 1.5777, 1.506 , 1.4691, 1.539 , 1.5592, 1.5688,
#        1.5264])

# %%
#Problem5.5
si2=[]
ssum2=0
for i in range (0,20):
    si2.append(np.sqrt(((chart2_a[i][0]-chart2_a[i][5])**2+(chart2_a[i][1]-chart2_a[i][5])**2+(chart2_a[i][2]-chart2_a[i][5])**2+(chart1_a[i][3]-chart1_a[i][5])**2
            +(chart2_a[i][4]-chart2_a[i][5])**2)/4))
    ssum2+=np.sqrt(((chart2_a[i][0]-chart2_a[i][5])**2+(chart2_a[i][1]-chart2_a[i][5])**2+(chart2_a[i][2]-chart2_a[i][5])**2+(chart1_a[i][3]-chart1_a[i][5])**2
            +(chart2_a[i][4]-chart2_a[i][5])**2)/4)
sbar2=ssum2/20
sigma2=sbar2/0.94
print('estimated sigma is %f'%sigma2)
xbarsum2=0
for i in range (0,20):
    xbarsum2+=chart2_a[i][5]
xbarbar2=xbarsum2/20

plt.figure(figsize=(8,4))
time=np.linspace(1,20,20)
xbar_a2=chart2_a[:,5]
plt.plot(time,xbar_a2,c='blue',marker='.',alpha=0.5,label='Configuration 1')
plt.hlines(xbarbar+1.427*sbar,1,20,linestyle="-")
plt.hlines(xbarbar,1,20,linestyle="-")
plt.hlines(xbarbar-1.427*sbar,1,20,linestyle="-")
plt.title('x bar chart Phase2') 
xbar_a
# Out:
# estimated sigma is 0.136659
# array([1.5119, 1.4951, 1.4817, 1.4712, 1.4882, 1.4492, 1.5805, 1.5343,
#        1.5076, 1.5134, 1.5242, 1.5284, 1.3947, 1.5261, 1.4083, 1.5344,
#        1.4874, 1.4573, 1.5777, 1.506 , 1.4691, 1.539 , 1.5592, 1.5688,
#        1.5264])

# %%
plt.figure(figsize=(8,4))
time=np.linspace(1,20,20)
plt.plot(time,si2,c='blue',marker='.',alpha=0.5,label='Configuration 1')
plt.hlines(sbar*2.089,1,20,linestyle="-")
plt.hlines(sbar,1,20,linestyle="-")
plt.hlines(0,1,20,linestyle="-")
plt.title('s chart Phase2') 
xbar_a
# Out:
# array([1.5119, 1.4951, 1.4817, 1.4712, 1.4882, 1.4492, 1.5805, 1.5343,
#        1.5076, 1.5134, 1.5242, 1.5284, 1.3947, 1.5261, 1.4083, 1.5344,
#        1.4874, 1.4573, 1.5777, 1.506 , 1.4691, 1.539 , 1.5592, 1.5688,
#        1.5264])
