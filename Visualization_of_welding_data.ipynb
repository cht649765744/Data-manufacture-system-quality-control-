# %% [markdown]
# # ME 498 HW1 Submission

# %%
# import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Homework 1 problem 1.1
test_data = np.array([[127, 124, 121, 118], [125, 123, 136, 131], [131, 120, 140, 125],
                      [124, 119, 137, 133], [129, 128, 125, 141], [121, 133, 124, 125],
                      [142, 137, 128, 140], [151, 124, 129, 131], [160, 142, 130, 129],
                      [125, 123, 122, 126]]).T.reshape((-1,))
# print(test_data.shape)

# ** your code here **
mean_1=np.mean(test_data)
std_1=np.std(test_data)
print('The average is %.3f'%mean_1)
print('The standard deviation is %.3f' %std_1)
# Out:
# The average is 129.975
# The standard deviation is 8.802

# %%
# Homework 1 problem 1.2
plt.hist(test_data, 10,label = ('Electronic Component Failure Time'))
plt.xlabel('failure time')
plt.ylabel('rate')
plt.title('Histogram for the test') 
plt.legend()

# %%
# Homework 1 problem 1.3
med=np.median(test_data)
quar=np.percentile(test_data,[25,75])
print('median=%s' %med)
print('lower quartiles=%s'%quar[0])
print('upper quartiles=%s'%quar[1])
# Out:
# median=128.0
# lower quartiles=124.0
# upper quartiles=133.75

# %%
t=np.array([[127, 124, 121, 118], [125, 123, 136, 131], [131, 120, 140, 125],
                      [124, 119, 137, 133], [129, 128, 125, 141], [121, 133, 124, 125],
                      [142, 137, 128, 140], [151, 124, 129, 131], [160, 142, 130, 129],
                      [125, 123, 122, 126]])

# %%
# Homework 1 problem 2
from sympy import *
x = symbols('x')
prob=integrate(4*(x-11.75), (x, 11.75, 12))
print('the probability is %f' %prob)
# Out:
# the probability is 0.125000

# %%
# Homework 1 problem 3.1
from scipy.stats import norm
xdev=norm.ppf(1-0.05/2)*0.0001/sqrt(25)
if (0.5025>=(0.5046-xdev)) & (5.5025<=(0.5046+xdev)):
    print('The hypothesis is true')
else: 
    print('The hypothesis is false')
# Out:
# The hypothesis is false

# %%
# Homework 1 problem 3.2
zz=(0.5046-0.5025)/(0.0001/sqrt(25))
p=2*(1-norm.pdf(105))
print('P - value is %s' %p)
# Out:
# P - value is 2.0

# %%
# Homework 1 problem 3.3
xdev=norm.ppf(1-0.05/2)*0.0001/sqrt(25)
upint=0.05046+xdev
loint=0.05046-xdev
print('The Convidence Interval is [%f,%f]'%(loint ,upint))
# Out:
# The Convidence Interval is [0.050421,0.050499]

# %%
# Homework 1 problem 4.1
# Example for importing supplied .csv file with pandas, 
# asssuming that the .csv file is placed in the same directory, right beside this python script
import pandas as pd

welding_dataf = pd.read_csv('welding_data(1).csv',header = 0,  index_col = None) # Read .csv file with pandas
# print(welding_dataf.head)
dataf_array = np.asanyarray(welding_dataf) # Convert pandas dataframe as numpy array
# print(dataf_array.shape)
# print(dataf_array[0, :])
print('The number of welds is %d'%len(dataf_array))
#welding_dataf
# Out:
# The number of welds is 11558

# %%
print(dataf_array[1])
# Out:
# [  2.   0. 131. 118. 110. 120.]

# %%
# Homework 1 problem 4.2
k=0
for n in range (0,11558):
    if dataf_array[n,1] >= 1:
        k=k+1
        
print('The defective rate is %f'%(k/11558))
# Out:
# The defective rate is 0.006749

# %%
# Homework 1 problem 4.3
welco=welding_dataf
welco.drop(['Configuration', 'Quality'],  axis=1 ,   inplace=True)
welco.corr()
# Out:
#            Feature 1  Feature 2  Feature 3  Feature 4
# Feature 1      1.000      0.356      0.090      0.019
# Feature 2      0.356      1.000      0.324     -0.298
# Feature 3      0.090      0.324      1.000     -0.907
# Feature 4      0.019     -0.298     -0.907      1.000

# %%
# Homework 1 problem 4.4
f1 = plt.figure()
times=np.arange(start=0,stop=11558,step=1)
dconf=dataf_array[:,0]
ddef=dataf_array[:,1]
dfea1=dataf_array[:,2]
dfea2=dataf_array[:,3]
dfea3=dataf_array[:,4]
dfea4=dataf_array[:,5]
plt.scatter(dfea3,dfea4)
np.corrcoef([dfea3,dfea4])
# Out:
# array([[ 1.        , -0.90746427],
#        [-0.90746427,  1.        ]])

# %%
# Homework 1 problem 4.5
#f2 = plt.figure()
plt.figure(figsize=(10,10))
plt.subplot(2, 2, 1)
plt.hist(dfea1, 10,label = ('Fearture 1'))
plt.xlabel('Feature 1')
plt.ylabel('Number')
plt.title('Histogram for Feature 1') 
plt.legend()
plt.subplot(2, 2, 2)
plt.hist(dfea2, 10,label = ('Fearture 2'))
plt.xlabel('Feature 2')
plt.ylabel('Number')
plt.title('Histogram for Feature 2') 
plt.legend()
plt.subplot(2, 2, 3)
plt.hist(dfea3, 10,label = ('Fearture 3'))
plt.xlabel('Feature 3')
plt.ylabel('Number')
plt.title('Histogram for Feature 3') 
plt.legend()
plt.subplot(2, 2, 4)
plt.hist(dfea4, 10,label = ('Fearture 4'))
plt.xlabel('Feature 4')
plt.ylabel('Number')
plt.title('Histogram for Feature 4') 
plt.legend()
plt.subplots_adjust(left=0, bottom=None, right=None, top=None,
                    wspace=0.3, hspace=0.3)

# %%
# Homework 1 problem 4.6

#pd.options.display.float_format = '{:,.3f}'.format
welding_dataf.describe()
# Out:
#        Feature 1  Feature 2  Feature 3  Feature 4
# count 11,558.000 11,558.000 11,558.000 11,558.000
# mean     133.028    115.812    105.407    116.050
# std        3.235      3.826      7.285      6.863
# min      124.000     91.000     78.750     92.000
# 25%      131.000    113.000     99.500    112.000
# 50%      133.000    116.000    105.250    116.000
# 75%      135.000    118.000    110.000    122.000
# max      150.000    151.000    130.250    170.000

# %%
# Homework 1 problem 4.7
k47=0
for n47 in range(0,11558):
    if dconf[n47]==1:
        k47=k47+1
print('Number of configuration 1 is %d. The percentage is  %f%% .' %(k47,(k47/11558)*100))
k47=0
for n47 in range(0,11558):
    if dconf[n47]==2:
        k47=k47+1
print('Number of configuration 2 is %d. The percentage is  %f%% .' %(k47,(k47/11558)*100))
k47=0
for n47 in range(0,11558):
    if dconf[n47]==3:
        k47=k47+1
print('Number of configuration 3 is %d. The percentage is  %f%% .' %(k47,(k47/11558)*100))
# Out:
# Number of configuration 1 is 1086. The percentage is  9.396089% .
# Number of configuration 2 is 5053. The percentage is  43.718636% .
# Number of configuration 3 is 5419. The percentage is  46.885274% .

# %%
# Homework 1 problem 4.8
de1=0
de2=0
de3=0
for nd in range(0,11558):
    if ddef[nd]==1:
        if dconf[nd]==1:
            de1=de1+1
        if dconf[nd]==2:
            de2=de2+1
        if dconf[nd]==3:
            de3=de3+1
print('defective rate of configuration 1 is %f%% \n\
defective rate of configuration 1 is %f%% \n\
defective rate of configuration 1 is %f%% \n' 
      %(100*de1/1086,100*de2/5053,100*de3/5419))
# Out:
# defective rate of configuration 1 is 0.368324%
# defective rate of configuration 1 is 1.246784%
# defective rate of configuration 1 is 0.202989%

# %%
# Homework 1 problem 4.9
welchar=pd.read_csv('welding_data(1).csv',header = 0,  index_col = None) # Read .csv file with pandas

welcon1=welchar.loc[welchar['Configuration']==1,['Feature 1','Feature 2','Feature 3','Feature 4']]
welcon2=welchar.loc[welchar['Configuration']==2,['Feature 1','Feature 2','Feature 3','Feature 4']]
welcon3=welchar.loc[welchar['Configuration']==3,['Feature 1','Feature 2','Feature 3','Feature 4']]
welcon1.corr()


#welchar.loc[welchar['gender']=='M',['name','age']] #选取g

#welding_dataf
# Out:
#            Feature 1  Feature 2  Feature 3  Feature 4
# Feature 1      1.000      0.481      0.109     -0.047
# Feature 2      0.481      1.000      0.525     -0.543
# Feature 3      0.109      0.525      1.000     -0.841
# Feature 4     -0.047     -0.543     -0.841      1.000

# %%
welcon2.corr()
# Out:
#            Feature 1  Feature 2  Feature 3  Feature 4
# Feature 1      1.000      0.142     -0.008      0.264
# Feature 2      0.142      1.000     -0.068      0.116
# Feature 3     -0.008     -0.068      1.000     -0.782
# Feature 4      0.264      0.116     -0.782      1.000

# %%
welcon3.corr()
# Out:
#            Feature 1  Feature 2  Feature 3  Feature 4
# Feature 1      1.000      0.481      0.109     -0.047
# Feature 2      0.481      1.000      0.525     -0.543
# Feature 3      0.109      0.525      1.000     -0.841
# Feature 4     -0.047     -0.543     -0.841      1.000

# %%
# Homework 1 problem 4.10
welchar=pd.read_csv('welding_data(1).csv',header = 0,  index_col = None) # Read .csv file with pandas

#add 'time series'
b=np.linspace(0,11557,11558)
welchar['Time']=b


welchar
welcon1=welchar.loc[welchar['Configuration']==1,['Time','Feature 1','Feature 2','Feature 3','Feature 4']]
welcon2=welchar.loc[welchar['Configuration']==2,['Time','Feature 1','Feature 2','Feature 3','Feature 4']]
welcon3=welchar.loc[welchar['Configuration']==3,['Time','Feature 1','Feature 2','Feature 3','Feature 4']]



welcon1_array = np.asanyarray(welcon1)
welcon2_array = np.asanyarray(welcon2)
welcon3_array = np.asanyarray(welcon3)
time1=welcon1_array[:,0]
time2=welcon2_array[:,0]
time3=welcon3_array[:,0]
dfea1_con1=welcon1_array[:,1]
dfea1_con2=welcon2_array[:,1]
dfea1_con3=welcon3_array[:,1]
dfea2_con1=welcon1_array[:,2]
dfea2_con2=welcon2_array[:,2]
dfea2_con3=welcon3_array[:,2]
dfea3_con1=welcon1_array[:,3]
dfea3_con2=welcon2_array[:,3]
dfea3_con3=welcon3_array[:,3]



plt.figure(figsize=(8,20))
#画图吧，s表示点点的大小，c就是color嘛，marker就是点点的形状哦o,x,*><^,都可以啦
#alpha,点点的亮度，label，标签啦
plt.subplot(3, 1, 1)
plt.scatter(time1,dfea1_con1,s=8,c='red',marker='o',alpha=0.5,label='Configuration 1')
plt.scatter(time2,dfea1_con2,s=8,c='blue',marker='x',alpha=0.5,label='Configuration 2')
plt.scatter(time3,dfea1_con3,s=8,c='green',marker='x',alpha=0.5,label='Configuration 3')
#下面三行代码很简单啦
plt.title('scatter for feature 1 ')
plt.xlabel('Time Series')
plt.ylabel('value')

plt.legend(loc='upper right')#这个必须有，没有你试试看

plt.show()#这个可以没有


plt.figure(figsize=(8,20))
plt.subplot(3, 1, 2)
plt.scatter(time1,dfea2_con1,s=8,c='red',marker='o',alpha=0.5,label='Configuration 1')
plt.scatter(time2,dfea2_con2,s=8,c='blue',marker='x',alpha=0.5,label='Configuration 2')
plt.scatter(time3,dfea2_con3,s=8,c='green',marker='x',alpha=0.5,label='Configuration 3')
#下面三行代码很简单啦
plt.title('scatter for feature 2 ')
plt.xlabel('Time Series')
plt.ylabel('value')

plt.legend(loc='upper right')#这个必须有，没有你试试看

plt.show()#这个可以没有




plt.figure(figsize=(8,20))
plt.subplot(3, 1, 3)
plt.scatter(time1,dfea3_con1,s=8,c='red',marker='o',alpha=0.5,label='Configuration 1')
plt.scatter(time2,dfea3_con2,s=8,c='blue',marker='x',alpha=0.5,label='Configuration 2')
plt.scatter(time3,dfea3_con3,s=8,c='green',marker='x',alpha=0.5,label='Configuration 3')
#下面三行代码很简单啦
plt.title('scatter for feature 3 ')
plt.xlabel('Time Series')
plt.ylabel('value')

plt.legend(loc='upper right')#这个必须有，没有你试试看

plt.show()#这个可以没有

# %%
# Homework 1 problem 4.11

welchar
# Out:
#        Configuration  Quality  Feature 1  Feature 2  Feature 3  Feature 4  \
# 0                  1        0        129        116    107.500        118
# 1                  2        0        131        118    110.000        120
# 2                  3        0        129        116    121.000        104
# 3                  2        0        133        115    115.000        114
# 4                  3        0        129        116    120.000        108
# 5                  2        0        131        114    108.500        116
# 6                  3        0        132        115    116.250        108
# 7                  2        0        130        117    117.750        108
# 8                  3        0        131        115    120.000        106
# 9                  2        0        131        117    115.500        108
# 10                 3        0        128        116    115.750        106
# 11                 2        0        130        115    119.250        108
# ...

# %%
# Homework 1 problem 4.12

##extract good and defective one seperately
welgood=welchar.loc[welchar['Quality']==0,['Time','Feature 1','Feature 2','Feature 3','Feature 4']]
welbad=welchar.loc[welchar['Quality']==1,['Time','Feature 1','Feature 2','Feature 3','Feature 4']]

##transfer datagram into array
welgood_array = np.asanyarray(welgood)
welbad_array = np.asanyarray(welbad)

#get the arrays used in the scatter
timegood=welgood_array[:,0]
timebad=welbad_array[:,0]
dfea1_good=welgood_array[:,1]
dfea1_bad=welbad_array[:,1]
dfea2_good=welgood_array[:,2]
dfea2_bad=welbad_array[:,2]
dfea3_good=welgood_array[:,3]
dfea3_bad=welbad_array[:,3]


##picture scatter for feature 1
plt.figure(figsize=(8,20))
#画图吧，s表示点点的大小，c就是color嘛，marker就是点点的形状哦o,x,*><^,都可以啦
#alpha,点点的亮度，label，标签啦
plt.subplot(3, 1, 1)
plt.scatter(timegood,dfea1_good,s=8,c='green',marker='o',alpha=0.5,label='good')
plt.scatter(timebad,dfea1_bad,s=18,c='red',marker='x',alpha=0.5,label='defective')
#下面三行代码很简单啦
plt.title('scatter for feature 1 ')
plt.xlabel('Time Series')
plt.ylabel('value')

plt.legend(loc='upper right')
plt.show()#

##picture scatter for feature 2
plt.figure(figsize=(8,20))
plt.subplot(3, 1, 2)
plt.scatter(timegood,dfea2_good,s=8,c='green',marker='o',alpha=0.5,label='good')
plt.scatter(timebad,dfea2_bad,s=18,c='red',marker='x',alpha=0.5,label='defective')
#下面三行代码很简单啦
plt.title('scatter for feature 2 ')
plt.xlabel('Time Series')
plt.ylabel('value')

plt.legend(loc='upper right')
plt.show()


##picture scatter for feature 3
plt.figure(figsize=(8,20))
plt.subplot(3, 1, 2)
plt.scatter(timegood,dfea3_good,s=8,c='green',marker='o',alpha=0.5,label='good')
plt.scatter(timebad,dfea3_bad,s=18,c='red',marker='x',alpha=0.5,label='defective')
#下面三行代码很简单啦
plt.title('scatter for feature 3 ')
plt.xlabel('Time Series')
plt.ylabel('value')

plt.legend(loc='upper right')
plt.show()

# %%
# Homework 1 problem 4.13

##picture histogram of feature 1
plt.figure(figsize=(8,15))

ax1f1 = plt.subplot(311)

ax1f1.hist(dfea1_good,10,facecolor='green', label = ('good'))
ax1f1.legend(loc='upper left')


ax2f1 = ax1f1.twinx()
ax2f1.hist(dfea1_bad, 10,facecolor='red',label = ('defective'),alpha=0.65)
ax2f1.legend(loc='upper right')
plt.title('quality histogram for feature 1 ')


##picture histogram of feature 2
plt.figure(figsize=(8,15))

ax1f2 = plt.subplot(312)

ax1f2.hist(dfea2_good,10,facecolor='green', label = ('good'))
ax1f2.legend(loc='upper left')


ax2f2 = ax1f2.twinx()
ax2f2.hist(dfea2_bad, 10,facecolor='red',label = ('defective'),alpha=0.65)
ax2f2.legend(loc='upper right')
plt.title('quality histogram for feature 2 ')


##picture histogram of feature 3
plt.figure(figsize=(8,15))

ax1f3 = plt.subplot(313)

ax1f3.hist(dfea3_good,10,facecolor='green', label = ('good'))
ax1f3.legend(loc='upper left')


ax2f3 = ax1f3.twinx()
ax2f3.hist(dfea3_bad, 10,facecolor='red',label = ('defective'),alpha=0.65)
ax2f3.legend(loc='upper right')
plt.title('quality histogram for feature 3 ')
# Out:
# Text(0.5,1,'quality histogram for feature 3 ')

# %%
# Homework 1 problem 4.14
wel14=pd.read_csv('welding_data(1).csv',header = 0,  index_col = None)

##extrat 
welgood14=wel14.loc[welchar['Quality']==0,['Feature 1','Feature 2','Feature 3','Feature 4']]
welbad14=wel14.loc[welchar['Quality']==1,['Feature 1','Feature 2','Feature 3','Feature 4']]
print('for Good quality')
welgood.describe()
# Out:
# for Good quality
#             Time  Feature 1  Feature 2  Feature 3  Feature 4
# count 11,480.000 11,480.000 11,480.000 11,480.000 11,480.000
# mean   5,776.802    132.950    115.857    105.430    115.952
# std    3,339.717      3.095      3.724      7.283      6.682
# min        0.000    124.000     96.000     87.750     92.000
# 25%    2,884.750    131.000    113.000     99.500    112.000
# 50%    5,774.500    133.000    116.000    105.250    116.000
# 75%    8,669.250    135.000    118.000    110.000    122.000
# max   11,557.000    148.000    130.000    130.250    142.000

# %%
print('for Defective quality')
welbad.describe()
# Out:
# for Defective quality
#             Time  Feature 1  Feature 2  Feature 3  Feature 4
# count     78.000     78.000     78.000     78.000     78.000
# mean   6,028.474    144.462    109.192    102.013    130.436
# std    2,857.077      3.145      9.196      6.794     14.192
# min      589.000    134.000     91.000     78.750    106.000
# 25%    4,949.500    143.000    103.000     98.312    122.000
# 50%    6,316.000    145.000    108.000    101.875    127.000
# 75%    8,598.500    147.000    113.000    104.750    134.000
# max   11,510.000    150.000    151.000    122.500    170.000

# %%
# Homework 1 problem 4.15

# %%
x = np.arange(0., np.e, 0.01)
y1 = np.exp(-x)
y2 = np.log(x)

fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot(x, y1,'r',label="right");
ax1.legend(loc=1)
ax1.set_ylabel('Y values for exp(-x)');


ax2 = ax1.twinx() # this is the important function
ax2.plot(x, y2, 'g',label = "left")
ax2.legend(loc=2)
#ax2.set_xlim([0, np.e]);
ax2.set_ylabel('Y values for ln(x)');
ax2.set_xlabel('Same X for both exp(-x) and ln(x)');
# Out:
# D:\Applications\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import numpy as np
welding_dataf
np_Feature 1=df['Feature 1'].values
# Out:
#   File "<ipython-input-141-a45c87969b9d>", line 3
#     np_Feature 1=df['Feature 1'].values
#                ^
# SyntaxError: invalid syntax

# %%
dfea1=dataf_array[:,2]
dfea2=dataf_array[:,3]
np.corrcoef([dfea1,dfea2])
# Out:
# array([[1.        , 0.35613777],
#        [0.35613777, 1.        ]])

# %%
a=norm.ppf(0.975)
a
# Out:
# 1.959963984540054

# %%
pd.

DataFrame.corr(method=’pearson’, min_periods=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-e9663b840573> in <module>()
# ----> 1 pd.DataFrame.corr()
#
# TypeError: corr() missing 1 required positional argument: 'self'

# %%
np.random.seed(123)
df1=pd.DataFrame( np.random.randn(3,2), columns=list('ab') )
df2=pd.DataFrame( np.random.randn(3,2), columns=list('ac') )

df1.corr()
# Out:
#        a      b
# a  1.000 -0.840
# b -0.840  1.000

# %%
welco=welding_dataf
welco.drop(['Configuration', 'Quality'],  axis=1 ,   inplace=True)
welco.corr()
# Out:
#            Feature 1  Feature 2  Feature 3  Feature 4
# Feature 1      1.000      0.356      0.090      0.019
# Feature 2      0.356      1.000      0.324     -0.298
# Feature 3      0.090      0.324      1.000     -0.907
# Feature 4      0.019     -0.298     -0.907      1.000
